# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import nltk
#nltk.download('stopwords')
print(tf.__version__)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 2.2.0

# %%
df_en_test = pd.read_csv('/content/drive/My Drive/abbyy/en_test')
df_ru_test = pd.read_csv('/content/drive/My Drive/abbyy/ru_test')
df_en_train = pd.read_csv('/content/drive/My Drive/abbyy/en_train')
df_ru_train = pd.read_csv('/content/drive/My Drive/abbyy/ru_train')

# %%
df_en_test.values.shape
# Out:
# (422, 3)

# %%
target_names = np.unique(df_en_train.target)
print(target_names)
# Out:
# ['A1' 'A11' 'A12' 'A14' 'A16' 'A17' 'A22' 'A4' 'A7' 'A8' 'A9']

# %%
X_train_ru, X_test_ru = df_ru_train['text'].values, df_ru_test['text'].values
y_train_ru, y_test_ru = df_ru_train['target'].values, df_ru_test['target'].values
X_train_en, X_test_en = df_en_train['text'].values, df_en_test['text'].values
y_train_en, y_test_en = df_en_train['target'].values, df_en_test['target'].values

# %% [markdown]
# ### Keyword extraction and writing them to csv files

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import string

def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []
    
    for idx, score in sorted_items:
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    results = {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]] = score_vals[idx]
    return results

def preprocess(text):
  lowercased = text.translate(str.maketrans("", "", string.punctuation)).lower()
  return ''.join([c for c in lowercased if not c.isdigit()])

def get_keywords_df(X_train, y_train, stop_words):
  cv = CountVectorizer(max_df=0.8, stop_words=stop_words)
  word_count_vector = cv.fit_transform(X_train)
  tfidf_transformer = TfidfTransformer(smooth_idf=True, use_idf=True)
  tfidf_transformer.fit(word_count_vector)

  topics_doc = {}
  for text, label in zip(X_train, y_train):
    if label not in topics_doc:
      topics_doc[label] = text
    else:
      topics_doc[label] += " " + text

  keywords_df = pd.DataFrame()
  feature_names = cv.get_feature_names()

  for topic_label, topic_text in topics_doc.items():
    topic_text = preprocess(topic_text)
    tf_idf_vector = tfidf_transformer.transform(cv.transform([topic_text]))
    sorted_items = sort_coo(tf_idf_vector.tocoo())
    keywords = extract_topn_from_vector(feature_names, sorted_items, 20)

    print("\n=====Doc=====")
    print(topic_text[:100])
    print("\n===Keywords===")
    for keyword in keywords:
        keywords_df = keywords_df.append({'keyword': keyword, 'topic': topic_label}, ignore_index=True)
        print(keyword, keywords[keyword])
  return keywords_df

# %%
keywords_ru = get_keywords_df(X_train_ru, y_train_ru, stopwords.words("russian") + ["это"])
# Out:
# =====Doc=====
# в ответ на  европейское турне  партии регионов тимошенко обратится в суд  украина  экспремьерминистр
#
# ===Keywords===
# заявил 0.235
# президент 0.182
# года 0.162
# млрд 0.149
# россии 0.143
# сша 0.141
# украины 0.128
# году 0.124
# газа 0.12
# также 0.112
# рф 0.106
# президента 0.101
# словам 0.097
# сообщает 0.093
# сказал 0.091
# глава 0.09
# изза 0.088
# долларов 0.086
# страны 0.085
# власти 0.08
#
# =====Doc=====
# электронная книга wexler t компания wexler объявляет о старте продаж новой электронной книги wexler
#
# ===Keywords===
# мм 0.207
# волос 0.162
# позволяет 0.143
# благодаря 0.136
# компания 0.118
# линзы 0.11
# модель 0.105
# компании 0.104
# также 0.095
# качества 0.086
# обеспечивает 0.076
# высокой 0.076
# система 0.073
# вес 0.071
# линз 0.07
# кг 0.069
# продукции 0.068
# является 0.066
# двери 0.065
# модели 0.065
#
# =====Doc=====
# комиссия по правам человека шестидесятая сессия пункт  повестки дня вопрос о нарушении прав человека
#
# ===Keywords===
# объединенных 0.14
# наций 0.14
# организации 0.14
# миростроительству 0.133
# безопасности 0.132
# которые 0.107
# комиссии 0.095
# человека 0.089
# совета 0.088
# также 0.088
# нам 0.086
# ознер 0.085
# ургинян 0.084
# является 0.082
# года 0.08
# лишь 0.078
# человек 0.077
# развития 0.073
# жизни 0.071
# сша 0.07
#
# =====Doc=====
# дмитрий анатольевич нам еще всем покажет  кто в доме хозяин  это уже его второе замечание в сторону
#
# ===Keywords===
# очень 0.228
# фильм 0.107
# хотя 0.104
# вполне 0.095
# книги 0.094
# кстати 0.093
# просто 0.09
# вообще 0.081
# гришковец 0.08
# читать 0.08
# сюжет 0.075
# ferrari 0.071
# сегодня 0.071
# интересно 0.069
# мало 0.064
# вроде 0.062
# игра 0.061
# хочется 0.059
# довольно 0.058
# которые 0.057
#
# =====Doc=====
# о путях построения типологии личности опубликовано  психологический журнал том  №   идея типологии
#
# ===Keywords===
# рис 0.141
# of 0.109
# исследования 0.106
# также 0.093
# является 0.092
# the 0.089
# теории 0.083
# личности 0.081
# развития 0.078
# см 0.078
# системы 0.075
# например 0.074
# др 0.068
# области 0.067
# напряжений 0.067
# основе 0.066
# and 0.065
# наука 0.064
# которые 0.062
# образом 0.06
#
# =====Doc=====
# ﻿ ii  а что  если уж и был обыск  что  если их как раз у себя и застану   но вот его комната  ничего
#
# ===Keywords===
# де 0.161
# сказала 0.149
# сказал 0.144
# br 0.132
# алиса 0.128
# эжен 0.114
# русалочка 0.107
# мато 0.092
# тебе 0.085
# горио 0.084
# геракл 0.083
# глаза 0.081
# всё 0.076
# ресто 0.075
# спендий 0.068
# очень 0.068
# спросил 0.067
# дориан 0.066
# егор 0.065
# просвирнин 0.064
#
# =====Doc=====
# я хотел бы рассказать немного о том  что мне нравится писать  я люблю погружаться в тему  о которой
#
# ===Keywords===
# br 0.812
# очень 0.092
# всё 0.083
# просто 0.073
# нам 0.069
# смех 0.064
# ещё 0.057
# хочу 0.052
# лет 0.05
# жизни 0.049
# petr 0.049
# lovigin 0.049
# спасибо 0.046
# думаю 0.046
# моей 0.045
# сванидзе 0.043
# время 0.042
# когнитивной 0.041
# которые 0.041
# ссср 0.04
#
# =====Doc=====
# школа  в широком смысле этого слова должна стать важнейшим фактором  формирования новых жизненных ус
#
# ===Keywords===
# федерации 0.286
# российской 0.248
# соответствии 0.161
# статьи 0.156
# ст 0.135
# статья 0.126
# диссертационного 0.124
# лица 0.118
# палата 0.102
# лиц 0.098
# организации 0.096
# настоящего 0.095
# прокурора 0.091
# почтовой 0.083
# livejournal 0.078
# совета 0.078
# ученой 0.077
# суда 0.076
# воздушного 0.076
# образования 0.075
#
# =====Doc=====
# вторая очередная сессия  года  сентября  года  ньюйорк пункт  предварительной повестки дня юнопс  фи
#
# ===Keywords===
# конвенции 0.202
# сторон 0.149
# года 0.13
# комитет 0.129
# также 0.118
# организации 0.115
# совещания 0.106
# деятельности 0.103
# объединенных 0.101
# наций 0.101
# стокгольмской 0.1
# моондрк 0.097
# комитета 0.096
# конференции 0.094
# секретариат 0.086
# закон 0.084
# азербайджанской 0.082
# сессии 0.08
# которые 0.08
# республики 0.075
#
# =====Doc=====
# глава  программы  управление программами запуск программ нажмите пуск  все программы  а затем нажмит
#
# ===Keywords===
# нажмите 0.613
# bluetooth 0.146
# windows 0.133
# настройка 0.117
# затем 0.114
# экране 0.105
# сети 0.105
# google 0.101
# выберите 0.1
# dns 0.098
# меню 0.098
# mobile 0.091
# om 0.085
# программы 0.084
# ip 0.081
# коммуникаторе 0.08
# коммуникатор 0.08
# коммуникатора 0.079
# кнопку 0.075
# настройки 0.075

# %%
keywords_ru.head()
# Out:
#      keyword topic
# 0     заявил    A8
# 1  президент    A8
# 2       года    A8
# 3       млрд    A8
# 4     россии    A8

# %%
keywords_ru.to_csv('/content/drive/My Drive/abbyy/keywords_ru.csv')

# %%
keywords_en = get_keywords_df(X_train_en, y_train_en, stopwords.words("english"))
# Out:
# =====Doc=====
# exchange rate disorder new york – two troubling features of the ongoing economic recovery are the de
#
# ===Keywords===
# peacebuilding 0.2
# children 0.168
# nt 0.152
# international 0.143
# council 0.139
# united 0.138
# nations 0.136
# commission 0.133
# security 0.125
# countries 0.111
# development 0.109
# conflict 0.108
# would 0.097
# states 0.096
# state 0.095
# political 0.094
# people 0.092
# armed 0.091
# also 0.086
# world 0.085
#
# =====Doc=====
# do you remember the debut of napster  say goodbye to cds and tape cassettes  for those that still ha
#
# ===Keywords===
# taft 0.307
# convention 0.231
# committee 0.222
# parties 0.2
# secretariat 0.168
# meeting 0.137
# sce 0.116
# shall 0.115
# mine 0.113
# conference 0.112
# states 0.103
# article 0.093
# roosevelt 0.086
# azerbaijan 0.084
# stockholm 0.082
# station 0.075
# would 0.075
# united 0.075
# pops 0.072
# scottish 0.07
#
# =====Doc=====
# have you heard about formbased codes  new zoning tool to be utilized with plan build live cincinnati
#
# ===Keywords===
# nt 0.237
# cialis 0.161
# viagra 0.148
# hotel 0.146
# online 0.13
# service 0.113
# th 0.106
# business 0.105
# writing 0.105
# posted 0.098
# tripadvisor 0.095
# help 0.091
# buy 0.088
# information 0.083
# work 0.083
# product 0.08
# customers 0.079
# essay 0.077
# services 0.076
# new 0.075
#
# =====Doc=====
# the sweets will be shipped as soon as possible  if the items ordered are in stock uk delivery takes
#
# ===Keywords===
# shall 0.551
# article 0.27
# court 0.228
# paragraph 0.225
# person 0.175
# prosecutor 0.168
# chamber 0.155
# may 0.144
# rule 0.12
# department 0.114
# order 0.103
# state 0.099
# registrar 0.094
# request 0.09
# accordance 0.09
# party 0.078
# street 0.077
# parties 0.076
# respect 0.071
# hhb 0.071
#
# =====Doc=====
# common symptoms of malware if you re seeing suspicious popups  unwanted toolbars  redirects  strange
#
# ===Keywords===
# device 0.301
# nt 0.281
# tap 0.25
# tab 0.191
# screen 0.184
# search 0.14
# bluetooth 0.123
# email 0.117
# settings 0.115
# information 0.101
# use 0.1
# iphone 0.098
# touch 0.095
# see 0.094
# google 0.093
# card 0.09
# may 0.089
# contact 0.088
# select 0.087
# click 0.081
#
# =====Doc=====
# they flee here for safety but are sent back to face death zimbabwes democrats live in fear of beatin
#
# ===Keywords===
# monuc 0.216
# said 0.155
# unops 0.137
# million 0.118
# committee 0.097
# nt 0.093
# report 0.092
# united 0.09
# programme 0.09
# disarmament 0.088
# congo 0.084
# government 0.084
# states 0.084
# also 0.083
# unomig 0.082
# demobilization 0.076
# international 0.075
# conference 0.074
# budget 0.073
# military 0.072
#
# =====Doc=====
# suppliers guide to eprocurement what are the benefits of eprocurement to suppliers  means our suppli
#
# ===Keywords===
# royal 0.438
# police 0.404
# military 0.389
# kitbag 0.219
# products 0.204
# football 0.18
# loan 0.143
# prices 0.12
# starting 0.114
# leisurewear 0.102
# range 0.096
# payday 0.095
# loans 0.094
# show 0.091
# available 0.088
# tyne 0.087
# newcastle 0.085
# online 0.084
# nt 0.082
# credit 0.079
#
# =====Doc=====
# held at the palais des nations  geneva  on wednesday   september   at  a  m  president  mr christian
#
# ===Keywords===
# nt 0.451
# th 0.232
# one 0.123
# church 0.118
# court 0.113
# cardiff 0.098
# really 0.095
# people 0.094
# get 0.089
# time 0.089
# would 0.088
# like 0.088
# know 0.086
# could 0.083
# think 0.083
# also 0.081
# judge 0.08
# tarifa 0.076
# menor 0.075
# years 0.074
#
# =====Doc=====
#  in which the plot thickens his visit to m de treville being paid  the pensive d  artagnan took the
#
# ===Keywords===
# said 0.308
# nt 0.296
# mme 0.167
# would 0.132
# one 0.124
# man 0.119
# could 0.109
# goriot 0.101
# little 0.1
# upon 0.099
# came 0.098
# like 0.094
# des 0.092
# de 0.091
# father 0.089
# went 0.085
# mick 0.084
# eyes 0.081
# eugene 0.079
# artagnan 0.076
#
# =====Doc=====
# stylized facts and experimentation charles crabtree  christopher j fariss university of michigan abs
#
# ===Keywords===
# faulttolerance 0.196
# system 0.171
# data 0.126
# software 0.12
# fault 0.118
# node 0.117
# image 0.115
# quantum 0.113
# faults 0.113
# eg 0.113
# ie 0.111
# fig 0.108
# wom 0.106
# error 0.1
# task 0.099
# recovery 0.099
# application 0.097
# eq 0.097
# function 0.095
# tiran 0.093
#
# =====Doc=====
# new star software  new star soccer  review games reviews sports sim reviews new star software new st
#
# ===Keywords===
# nt 0.546
# karma 0.185
# tv 0.146
# google 0.136
# drone 0.135
# home 0.096
# cnet 0.083
# like 0.081
# shoes 0.079
# oled 0.078
# gopro 0.078
# camera 0.078
# one 0.075
# star 0.072
# good 0.069
# new 0.068
# game 0.067
# features 0.066
# also 0.064
# music 0.063

# %%
keywords_en.head()
# Out:
#          keyword topic
# 0  peacebuilding    A1
# 1       children    A1
# 2             nt    A1
# 3  international    A1
# 4        council    A1

# %%
keywords_en.to_csv('/content/drive/My Drive/abbyy/keywords_en.csv')

# %% [markdown]
# ### Finding of the most frequent words and writing them to file

# %%
def write_most_frequent_words(X_train, stopwords, filename, count=50):
  count_dict = dict()
  for text in X_train:
    prepr_text = preprocess(text)
    for word in prepr_text.split():
      if word not in count_dict:
        count_dict[word] = 0
      if word not in stopwords:
        count_dict[word] += 1
  sorted_dict = sorted([(count, word) for word, count in count_dict.items()], reverse=True)[:count]
  
  with open(filename, 'w') as fout:
    for _, word in sorted_dict:
      fout.write(word + "\n")

# %%
write_most_frequent_words(X_train_ru, stopwords.words("russian") + ["это"], '/content/drive/My Drive/abbyy/frequent_words_ru')
write_most_frequent_words(X_train_en, stopwords.words("english"), '/content/drive/My Drive/abbyy/frequent_words_en')

# %%
# !cat '/content/drive/My Drive/abbyy/frequent_words_ru'
# Out:
# —
# «
# »
# также
# –
# которые
# года
# время
# м
# является
# организации
# который
# очень
# г
# российской
# федерации
# могут
# br
# лет
# россии
# т
# соответствии
# которых
# работы
# других
# человека
# связи
# этих
# области
# случае
# однако
# безопасности
# году
# “
# сша
# образом
# ”
# своей
# жизни
# деятельности
# которая
# развития
# имеет
# например
# должны
# системы
# поэтому
# статьи
# наций
# статья
