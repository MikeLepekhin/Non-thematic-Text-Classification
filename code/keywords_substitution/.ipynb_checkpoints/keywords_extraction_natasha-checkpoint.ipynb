# %%
#!pip install pymorphy2==0.8

# %%
import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import nltk
from os.path import join as pathjoin
import tqdm
#nltk.download('stopwords')
print(tf.__version__)
# Out:
# 2.3.0

# %%
DATA_DIR = '/home/mlepekhin/data'
MODELS_DIR = '/home/mlepekhin/models'

# %%
df_ru_train = pd.read_csv(pathjoin(DATA_DIR, 'ru_train'))

# %%
target_names = np.unique(df_ru_train.target)
print(target_names)
# Out:
# ['A1' 'A11' 'A12' 'A14' 'A16' 'A17' 'A4' 'A7' 'A8' 'A9']

# %%
X_train_ru = df_ru_train['text'].values
y_train_ru = df_ru_train['target'].values

# %% [markdown]
# ### POS extraction

# %%
from natasha import Doc, Segmenter, MorphVocab, NewsEmbedding, NewsMorphTagger

segmenter = Segmenter()
morph_vocab = MorphVocab()
emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)

# %%
pos_list = ['ADV', 'ADJ', 'NOUN', 'VERB']

def extract_pos_dataset(X_train):
    result_df = {'ADV': [], 'ADJ': [], 'NOUN': [], 'VERB': []}
    #last_sentence = {'ADV': '', 'ADJ': '', 'NOUN': '', 'VERB': ''}
    
    
    for sent in tqdm.tqdm(X_train):
        doc = Doc(sent)
        doc.segment(segmenter)
        doc.tag_morph(morph_tagger)
        last_sentence = {'ADV': '', 'ADJ': '', 'NOUN': '', 'VERB': ''}
        
        for token in doc.tokens:
            if token.pos in pos_list:
                last_sentence[token.pos] += ' ' + token.text
        for pos, value in last_sentence.items():
            if len(value):
                result_df[pos].append(value)
    return result_df

# %%
ru_pos_df = extract_pos_dataset(X_train_ru)
# Out:
# 100%|██████████| 1447/1447 [01:47<00:00, 13.41it/s]

# %%
print(ru_pos_df['NOUN'][500])
# Out:
#  году месяца кг живот бока здоровьем диету раз коллектив работе тётеньки-сладкоежки катагорически отвесики трубку мама гудка горлом канаве Спасибо филе судака грибами день диеты-это ленивой капец меню ходу дела разнообразие кд результаты января отвес кг объемах меню блюда мясо углеводности настроение поготовить Девочки вопрос консерв рыбные капустой кальмарами консерве содержимое банки состав сахар уксус итд жир-столько-то белок-столько-то Углеводы сахар составе Завтрак яичница яиц колбасой сыром куска курицы уе помидора оругчика сыра уе Чай сахара кола-лайт наела мнения вкуса количествах консервы сахар горбушу банке разнообразия

# %% [markdown]
# ### Keyword extraction and writing them to csv files

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import string

def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []
    
    for idx, score in sorted_items:
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    results = {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]] = score_vals[idx]
    return results

def preprocess(text):
    lowercased = text.translate(str.maketrans("", "", string.punctuation)).lower()
    return ''.join([c for c in lowercased if not c.isdigit()])

def get_keywords_df(X_train, y_train, stop_words):
    cv = CountVectorizer(max_df=0.8, stop_words=stop_words)
    word_count_vector = cv.fit_transform(X_train)
    tfidf_transformer = TfidfTransformer(smooth_idf=True, use_idf=True)
    tfidf_transformer.fit(word_count_vector)

    topics_doc = {}
    for text, label in zip(X_train, y_train):
        if label not in topics_doc:
            topics_doc[label] = text
        else:
            topics_doc[label] += " " + text

        keywords_df = pd.DataFrame()
        feature_names = cv.get_feature_names()

    for topic_label, topic_text in topics_doc.items():
        topic_text = preprocess(topic_text)
        tf_idf_vector = tfidf_transformer.transform(cv.transform([topic_text]))
        sorted_items = sort_coo(tf_idf_vector.tocoo())
        keywords = extract_topn_from_vector(feature_names, sorted_items, 20)

        print("\n=====Doc=====")
        print(topic_text[:100])
        print("\n===Keywords===")
        for keyword in keywords:
            keywords_df = keywords_df.append({'keyword': keyword, 'topic': topic_label}, ignore_index=True)
            print(keyword, keywords[keyword])
    return keywords_df

# %%
keywords_ru_noun = get_keywords_df(ru_pos_df['NOUN'], y_train_ru, stopwords.words("russian") + ["это"])
keywords_ru_adj = get_keywords_df(ru_pos_df['ADJ'], y_train_ru, stopwords.words("russian") + ["это"])
keywords_ru_adv = get_keywords_df(ru_pos_df['ADV'], y_train_ru, stopwords.words("russian") + ["это"])
keywords_ru_verb = get_keywords_df(ru_pos_df['VERB'], y_train_ru, stopwords.words("russian") + ["это"])
# Out:
# =====Doc=====
#  оао создания комплекса мощностью млн год директор оао таиф компания группы председатель совета дире
#
# ===Keywords===
# года 0.314
# млрд 0.217
# президент 0.207
# году 0.172
# газа 0.132
# словам 0.128
# млн 0.122
# президента 0.121
# власти 0.117
# глава 0.113
# страны 0.11
# время 0.099
# ходе 0.099
# долларов 0.097
# нефть 0.087
# марта 0.087
# компании 0.086
# сентября 0.083
# рублей 0.08
# апреля 0.078
#
# =====Doc=====
#  ходе написания ходатайства образцу постановлений заголовка вводную подозреваемый делу материалы дел
#
# ===Keywords===
# лет 0.196
# людей 0.135
# время 0.134
# жизни 0.125
# смех 0.12
# отец 0.116
# люди 0.107
# жизнь 0.102
# спасибо 0.097
# человек 0.095
# году 0.086
# книги 0.086
# работа 0.076
# психологии 0.073
# человека 0.072
# год 0.072
# мам 0.071
# работы 0.07
# день 0.07
# город 0.069
#
# =====Doc=====
#  опливо характеристики испытаний замеров раткая характеристика оборудования котла хема измерений кот
#
# ===Keywords===
# исследования 0.132
# теории 0.117
# развития 0.112
# личности 0.108
# системы 0.103
# области 0.098
# рис 0.097
# др 0.094
# наук 0.086
# работы 0.085
# жизни 0.084
# основе 0.083
# образом 0.08
# науки 0.078
# процессов 0.075
# время 0.074
# данных 0.074
# языка 0.074
# колебаний 0.074
# человека 0.07
#
# =====Doc=====
#  человечество целей стремление идеалу совершенству стремление перфекционизм психики грань желание ми
#
# ===Keywords===
# года 0.194
# деятельности 0.165
# совещания 0.152
# конвенции 0.147
# сессии 0.125
# комитет 0.113
# секретариат 0.109
# разминированию 0.107
# стран 0.106
# помощи 0.104
# доклад 0.103
# отношении 0.097
# вопросам 0.097
# секретариата 0.096
# рамках 0.096
# работы 0.095
# экспертов 0.092
# осуществления 0.09
# развития 0.087
# ведения 0.084
#
# =====Doc=====
#  сайдинг отделка дома сайдинг отделки стен цоколя дома материал зданий предприятий отделка дома вид
#
# ===Keywords===
# мм 0.238
# волос 0.211
# компания 0.137
# компании 0.136
# модель 0.127
# качества 0.114
# модели 0.113
# система 0.092
# время 0.089
# вес 0.089
# материалов 0.087
# техники 0.082
# эксплуатации 0.081
# характеристики 0.081
# производства 0.08
# продукции 0.08
# работы 0.077
# использования 0.077
# системы 0.077
# мебели 0.076
#
# =====Doc=====
#  софия ананке ногами потолке ноги потолка наги софия  ананке окном снег окном углом снег конца мозол
#
# ===Keywords===
# сыновья 0.169
# глаза 0.142
# русалочка 0.127
# женщина 0.12
# руки 0.118
# человек 0.117
# письмо 0.109
# время 0.105
# сердце 0.103
# руку 0.101
# голову 0.094
# лицо 0.093
# день 0.087
# сыновей 0.085
# дело 0.082
# дверь 0.081
# папаша 0.079
# лет 0.078
# дом 0.078
# доме 0.077
#
# =====Doc=====
#  окрашивание технологий университет программистка ведущей компанииразработчика обеспечения плане удо
#
# ===Keywords===
# детей 0.23
# миростроительству 0.181
# человека 0.131
# развития 0.121
# года 0.112
# мира 0.11
# жизни 0.107
# страны 0.103
# стран 0.101
# время 0.096
# вопрос 0.095
# человек 0.093
# секретаря 0.092
# области 0.092
# миростроительства 0.091
# безопасности 0.09
# общества 0.088
# конфликтах 0.087
# государства 0.087
# лет 0.083
#
# =====Doc=====
#  матче дождем сил ворота гол восторга синие конце тайма достоинством блин пенальти сердце горя врата
#
# ===Keywords===
# фильм 0.202
# игра 0.147
# сюжет 0.131
# книги 0.128
# ссылок 0.121
# кино 0.111
# фильма 0.11
# время 0.107
# фильме 0.095
# млн 0.088
# мыло 0.087
# день 0.084
# ссылки 0.084
# кафе 0.076
# кун 0.071
# детектор 0.07
# рецензия 0.067
# деньги 0.067
# поиск 0.066
# лет 0.065
#
# =====Doc=====
#  даты мастерклассов мая года регистрация участников апреля года программы фестиваля залы ул рымский
#
# ===Keywords===
# соответствии 0.228
# статьи 0.212
# ст 0.179
# статья 0.174
# договора 0.164
# лица 0.149
# лиц 0.135
# совета 0.11
# отношении 0.1
# право 0.1
# случае 0.098
# права 0.098
# связи 0.095
# организации 0.095
# оборудования 0.091
# пунктом 0.089
# порядке 0.088
# законодательства 0.088
# лицо 0.084
# государства 0.079
#
# =====Doc=====
#  глава экран d управление устройствами платформе экран d доступ касанием пальца функциям контакты со
#
# ===Keywords===
# почты 0.324
# нажмите 0.257
# эл 0.246
# экране 0.187
# настройка 0.167
# меню 0.157
# сообщения 0.139
# сети 0.138
# вкладке 0.133
# коммуникаторе 0.133
# экран 0.132
# коммуникатор 0.115
# поиска 0.111
# экрана 0.11
# коммуникатора 0.109
# см 0.108
# программы 0.107
# настройки 0.107
# сведения 0.105
# кнопку 0.097
#
# =====Doc=====
#  этиленового генеральный материнская третьем  чистой третьем  чистую текущего чистая известно высший
#
# ===Keywords===
# воздушного 0.259
# российской 0.196
# национальных 0.184
# необходимо 0.13
# других 0.124
# должны 0.114
# различных 0.106
# генерального 0.097
# другие 0.085
# новые 0.082
# второй 0.08
# демократической 0.079
# нужно 0.079
# новых 0.079
# должен 0.076
# иностранных 0.074
# воздушных 0.074
# профессионального 0.074
# настоящего 0.073
# новой 0.072
#
# =====Doc=====
#  следственных уголовному уголовного положено общем уголовное п должен двойном тетрадном длиннее угло
#
# ===Keywords===
# российской 0.167
# генеральной 0.156
# международного 0.146
# настоящего 0.141
# других 0.122
# электронной 0.121
# отдельной 0.111
# должны 0.11
# государственной 0.105
# римской 0.104
# английского 0.101
# государственного 0.093
# генеральная 0.092
# условных 0.089
# федеральным 0.084
# необходимо 0.083
# святого 0.083
# физической 0.082
# нужно 0.081
# образовательной 0.079
#
# =====Doc=====
#  етодика техническая налаживаемого аблица водная результатов езультаты ежимная водогрейного перативн
#
# ===Keywords===
# земельного 0.252
# российской 0.246
# транспортного 0.212
# настоящей 0.162
# налогового 0.153
# настоящего 0.146
# земельных 0.141
# должны 0.138
# необходимо 0.12
# других 0.117
# научного 0.105
# местного 0.103
# взрывоопасных 0.101
# государственной 0.099
# технического 0.097
# научных 0.096
# пелагических 0.096
# нужно 0.095
# другие 0.082
# насильственного 0.082
#
# =====Doc=====
#  лучшему амбициозных подобное полезным человеческой совершенным навязчивой патологической легко данн
#
# ===Keywords===
# стокгольмской 0.322
# стойких 0.202
# других 0.165
# органических 0.16
# минной 0.134
# противоминной 0.123
# бездомных 0.118
# седьмой 0.114
# должны 0.114
# базельской 0.112
# впитывающее 0.109
# продовольственной 0.106
# синий 0.104
# другие 0.102
# меньшей 0.101
# необходимо 0.098
# вспомогательных 0.093
# политической 0.089
# природоохранных 0.084
# межправительственный 0.082
#
# =====Doc=====
#  виниловый виниловый современный строительный жилых коммерческих торговых привлекательный стильный в
#
# ===Keywords===
# предварительного 0.282
# должны 0.153
# российской 0.15
# международного 0.145
# других 0.137
# правило 0.13
# демократической 0.125
# должна 0.116
# письменном 0.106
# необходимо 0.1
# другие 0.097
# генеральной 0.091
# судебная 0.089
# настоящей 0.088
# соответствующего 0.088
# должен 0.086
# должно 0.082
# федерального 0.079
# избирательной 0.074
# соответствующих 0.074
#
# =====Doc=====
#  сестринские грустно софия  новый нетрудно городские камонской циртские простыми бодрым каменные тяж
#
# ===Keywords===
# внутренней 0.268
# частной 0.212
# должны 0.152
# первичный 0.135
# других 0.118
# другие 0.117
# синтаксического 0.117
# необходимо 0.111
# двусоставного 0.109
# нужно 0.102
# должен 0.102
# нулевого 0.099
# русского 0.097
# возвратных 0.089
# новые 0.087
# самым 0.085
# частную 0.081
# субъектной 0.079
# электронной 0.075
# новый 0.075
#
# =====Doc=====
#  африканских массачусетский технологический целеустремленная молодая программного компьютерным крупн
#
# ===Keywords===
# диссертационного 0.54
# ученой 0.326
# муниципального 0.224
# диссертационный 0.212
# российской 0.14
# местного 0.105
# статистической 0.102
# других 0.094
# муниципальных 0.091
# международных 0.073
# настоящего 0.073
# нужно 0.067
# должны 0.066
# космическом 0.064
# татарского 0.062
# самом 0.061
# правовых 0.06
# ученых 0.058
# должен 0.058
# ежегодной 0.057
#
# =====Doc=====
#  вчерашнем проливным первый первого правый доволен голевые подобных синих красных общем негативные з
#
# ===Keywords===
# минимальных 0.374
# государственного 0.209
# административного 0.145
# русской 0.13
# должны 0.121
# других 0.111
# другие 0.107
# должностных 0.103
# настоящей 0.099
# юридических 0.094
# национальной 0.09
# государственному 0.081
# местного 0.079
# нелинейной 0.076
# соответствующие 0.075
# оперативного 0.074
# различных 0.074
# духовного 0.074
# российской 0.073
# государственном 0.073
#
# =====Doc=====
#      центральном  вал октябрьская открыты    международному педагогическую художественные различных
#
# ===Keywords===
# российской 0.451
# почтовой 0.322
# генерального 0.268
# генеральной 0.267
# главного 0.243
# должны 0.167
# федерального 0.149
# почтовых 0.124
# международного 0.123
# прокуратур 0.122
# должностные 0.112
# должностными 0.109
# настоящей 0.105
# персональных 0.104
# прокурорского 0.1
# должностных 0.097
# соответствующих 0.092
# международных 0.08
# палестинских 0.075
# транспортных 0.075
#
# =====Doc=====
#  начальный сенсорное начальный избранные начальном следующие главная настройка избранные начального
#
# ===Keywords===
# избранные 0.235
# неблагоприятных 0.175
# латвийской 0.121
# фондовой 0.121
# учетной 0.119
# начальном 0.112
# эл 0.11
# янтарная 0.11
# других 0.104
# святого 0.103
# сенситивные 0.092
# кимакского 0.092
# основные 0.089
# критические 0.088
# различных 0.088
# критических 0.087
# разных 0.084
# рабочего 0.082
# главная 0.076
# дополнительные 0.075
# =====Doc=====
#  ранее ранее сильно ранее сегодня сегодня более  ранее  также также так недавно  действительно еще т
#
# ===Keywords===
# также 0.5
# очень 0.277
# однако 0.198
# поэтому 0.197
# например 0.166
# сегодня 0.163
# включая 0.141
# затем 0.139
# почему 0.133
# наиболее 0.132
# вместе 0.127
# особенно 0.112
# часто 0.11
# менее 0.106
# пока 0.106
# ранее 0.096
# назад 0.094
# ещё 0.094
# снова 0.091
# вполне 0.089
#
# =====Doc=====
#  потом потом потом неминуемо хватить потому обычно иногда например еще там обычно еще гдето такто  д
#
# ===Keywords===
# также 0.547
# очень 0.237
# поэтому 0.18
# сегодня 0.172
# например 0.163
# однако 0.158
# особенно 0.143
# наиболее 0.141
# включая 0.137
# действительно 0.134
# затем 0.124
# вместе 0.121
# менее 0.117
# полностью 0.113
# ещё 0.109
# далее 0.102
# наверное 0.098
# почему 0.089
# вправе 0.087
# попрежнему 0.085
#
# =====Doc=====
#  наиболее очень менее более менее более снаружи где где где где здесь далее здесь далее где где где
#
# ===Keywords===
# также 0.576
# очень 0.29
# включая 0.193
# поэтому 0.185
# однако 0.176
# затем 0.172
# например 0.161
# сегодня 0.154
# особенно 0.149
# попрежнему 0.123
# вправе 0.116
# наиболее 0.112
# назад 0.107
# ещё 0.102
# вместе 0.097
# действительно 0.089
# менее 0.089
# полностью 0.088
# одновременно 0.088
# вниз 0.087
#
# =====Doc=====
#  конечно однако всегда как довольно временами тогда неслучайно много однако положительно теперь как
#
# ===Keywords===
# также 0.426
# затем 0.335
# например 0.236
# далее 0.229
# поэтому 0.202
# почему 0.154
# менее 0.152
# очень 0.145
# однако 0.14
# сразу 0.127
# довольно 0.126
# вместе 0.117
# вообще 0.109
# полностью 0.107
# сегодня 0.107
# позднее 0.104
# ранее 0.098
# выше 0.096
# дальше 0.093
# возможно 0.089
#
# =====Doc=====
#  можно достаточно немного вместе дома можно весьма хорошо вместе особенно очень значительно более оч
#
# ===Keywords===
# также 0.479
# очень 0.285
# однако 0.236
# затем 0.215
# например 0.212
# поэтому 0.17
# сегодня 0.154
# пока 0.136
# вместе 0.134
# попрежнему 0.127
# особенно 0.123
# полностью 0.115
# оптом 0.111
# обычно 0.104
# менее 0.098
# ранее 0.095
# далее 0.092
# весьма 0.089
# сразу 0.086
# вновь 0.085
#
# =====Doc=====
#  весело весело вдвоем  менее  везде где весьма еще так помаленьку снизу включая конечно так как вдру
#
# ===Keywords===
# также 0.428
# очень 0.281
# далее 0.207
# менее 0.199
# однако 0.188
# примерно 0.136
# особенно 0.13
# поэтому 0.127
# вчера 0.125
# полностью 0.124
# последовательно 0.121
# действительно 0.12
# вместе 0.109
# несмотря 0.108
# снова 0.107
# настолько 0.106
# часто 0.104
# сегодня 0.103
# затем 0.103
# довольно 0.098
#
# =====Doc=====
#  быстро серьезно более так сегодня полностью совсем так также предположительно однако вероятно гораз
#
# ===Keywords===
# также 0.429
# очень 0.243
# например 0.233
# однако 0.222
# затем 0.168
# менее 0.155
# включая 0.151
# поэтому 0.14
# вместе 0.124
# попрежнему 0.116
# совершенно 0.116
# ещё 0.108
# вообще 0.106
# наиболее 0.105
# сегодня 0.105
# практически 0.103
# полностью 0.102
# особенно 0.099
# выше 0.098
# ранее 0.092
#
# =====Doc=====
#  также очно так заочно так более менее менее более дополнительно менее  четырежды также позднее подр
#
# ===Keywords===
# также 0.587
# однако 0.239
# например 0.209
# очень 0.187
# включая 0.178
# наиболее 0.166
# поэтому 0.16
# сегодня 0.155
# попрежнему 0.139
# следовательно 0.136
# вместе 0.127
# особенно 0.125
# подробнее 0.122
# весьма 0.115
# вообще 0.097
# менее 0.096
# почему 0.086
# практически 0.084
# напротив 0.079
# назад 0.077
#
# =====Doc=====
#  сегодня более  еще пока поэтому рядом заодно специально теперь когда уже как поэтому хм  также уже
#
# ===Keywords===
# также 0.38
# затем 0.271
# очень 0.265
# сразу 0.186
# поэтому 0.169
# однако 0.148
# вполне 0.144
# впервые 0.143
# сегодня 0.14
# снова 0.128
# ранее 0.12
# например 0.115
# назад 0.106
# наиболее 0.103
# частично 0.099
# несмотря 0.095
# вероятно 0.094
# менее 0.094
# автоматически 0.093
# включая 0.091
#
# =====Doc=====
#  также  сначала так несколько конечно всегда очень очень дружелюбно всегда очень вместе както однако
#
# ===Keywords===
# также 0.696
# например 0.221
# включая 0.207
# очень 0.181
# однако 0.145
# сегодня 0.128
# поэтому 0.12
# наиболее 0.111
# полностью 0.102
# независимо 0.097
# весьма 0.095
# вообще 0.086
# сразу 0.085
# почему 0.081
# выше 0.079
# попрежнему 0.078
# прежде 0.075
# периодически 0.072
# далеко 0.072
# особенно 0.071
#
# =====Doc=====
#  отказывается сообщил получило получила увеличилась стало удовлетворил рассматривает предполагается
#
# ===Keywords===
# нажмите 0.415
# объединенных 0.248
# является 0.184
# заявил 0.147
# могут 0.131
# сказал 0.106
# следует 0.105
# имеет 0.104
# говорит 0.097
# могли 0.092
# сделать 0.088
# хотел 0.086
# являются 0.083
# использовать 0.083
# позволяет 0.081
# обеспечить 0.078
# руководящих 0.077
# см 0.077
# стал 0.074
# соединенных 0.072
#
# =====Doc=====
#  сделать есть рассмотрев установил закончим изложенного руководствуясь регламентируют прекратить изъ
#
# ===Keywords===
# вооруженных 0.452
# объединенных 0.312
# говорит 0.147
# является 0.147
# хотел 0.138
# включенных 0.11
# занять 0.089
# могут 0.086
# приглашаю 0.084
# являются 0.083
# следует 0.081
# затронутых 0.08
# выступить 0.08
# сказал 0.079
# позволяет 0.078
# имеет 0.073
# выразить 0.069
# касается 0.067
# сделать 0.066
# знаю 0.065
#
# =====Doc=====
#  ависимость ланзадание установленного используемых содержит установленного приведены установленного
#
# ===Keywords===
# могут 0.229
# является 0.216
# объединенных 0.187
# имеет 0.137
# принимает 0.118
# являются 0.115
# см 0.114
# окружающей 0.096
# следует 0.092
# уведомляет 0.087
# применяются 0.087
# принять 0.084
# говорит 0.082
# представляет 0.077
# можете 0.076
# существует 0.075
# состоит 0.074
# имеют 0.073
# идет 0.072
# делать 0.071
#
# =====Doc=====
#  заставляло меняться эволюционировать достигать называют бывает определить сделать становится давайт
#
# ===Keywords===
# рекомендовано 0.377
# рекомендовал 0.229
# объединенных 0.219
# затронутых 0.14
# создан 0.137
# руководящих 0.125
# является 0.122
# пострадавшим 0.11
# могут 0.089
# следует 0.085
# ввёл 0.084
# имеет 0.082
# предложил 0.077
# условлено 0.076
# участвовавших 0.075
# отметил 0.074
# обсудил 0.072
# стал 0.071
# являются 0.069
# имеющие 0.066
#
# =====Doc=====
#  сайдингом предназначен применять сайдингом придает обеспечивает отличается может справиться делает
#
# ===Keywords===
# является 0.269
# могут 0.152
# позволяет 0.144
# имеет 0.135
# хотел 0.121
# являются 0.12
# объединенных 0.117
# следует 0.116
# сказал 0.115
# сделать 0.109
# можем 0.109
# сказать 0.104
# использовать 0.097
# можете 0.09
# мог 0.087
# означает 0.087
# заявил 0.082
# имеют 0.079
# думаю 0.078
# становится 0.077
#
# =====Doc=====
#  знает знает идет живут смеются идет обнажая ананке следить  выступили дали расположились сказали уб
#
# ===Keywords===
# развивающихся 0.187
# является 0.169
# сказал 0.141
# могут 0.135
# предусмотренного 0.112
# спросил 0.106
# совершенное 0.102
# существует 0.095
# существующих 0.088
# развивающимися 0.085
# являются 0.084
# превышать 0.082
# думаю 0.082
# включенных 0.079
# стали 0.076
# назначается 0.073
# имеют 0.073
# пришлось 0.071
# имеет 0.07
# касается 0.069
#
# =====Doc=====
#  забудьте здравствует мечтает усовершенствовать планирует поступить устанавливает сделанное является
#
# ===Keywords===
# объединенных 0.257
# является 0.255
# см 0.18
# могут 0.167
# говорит 0.147
# сказал 0.143
# имеет 0.143
# являются 0.108
# сказала 0.104
# хотел 0.103
# следует 0.096
# стоит 0.088
# имеют 0.084
# стали 0.081
# обеспечить 0.078
# существует 0.077
# осуществляется 0.074
# сделать 0.074
# стал 0.073
# развивающихся 0.072
#
# =====Doc=====
#  завершившемся болел сказать влетел прыгал отыгрались произнес забил разорвалось угадав отбил умер с
#
# ===Keywords===
# могут 0.152
# объединенных 0.148
# можете 0.133
# находящихся 0.118
# следует 0.117
# развивающихся 0.108
# сказала 0.108
# запрещены 0.099
# оплатить 0.093
# имеет 0.091
# является 0.09
# принимается 0.089
# говорит 0.087
# приветствуются 0.086
# имеют 0.08
# могу 0.079
# обеспечить 0.079
# предусмотренные 0.077
# получить 0.075
# осуществляется 0.075
#
# =====Doc=====
#  пройдут обратите имеют провести перейти предложить скачать скачать осуществляющие имеющие имеют при
#
# ===Keywords===
# объединенных 0.447
# приравненных 0.196
# влечет 0.18
# могут 0.166
# указанных 0.148
# принимает 0.145
# имеет 0.138
# организуют 0.116
# является 0.115
# установленном 0.11
# предусмотренных 0.108
# действующего 0.092
# являются 0.089
# обеспечивает 0.084
# организует 0.083
# издаваемых 0.081
# действующих 0.077
# установленных 0.076
# имеют 0.075
# нажмите 0.074
#
# =====Doc=====
#  обеспечивает обеспечивает используемым есть отображаются выдвинуть изменится показать нажмите разве
#
# ===Keywords===
# нажмите 0.806
# определяющий 0.135
# открыть 0.121
# могут 0.121
# откройте 0.121
# позвонить 0.108
# выберите 0.099
# просмотреть 0.094
# добавить 0.094
# выбрать 0.09
# содержит 0.089
# наносят 0.087
# удалить 0.083
# хотите 0.08
# ввести 0.07
# отправить 0.067
# определяющего 0.063
# использовать 0.061
# является 0.056
# соглашаетесь 0.056

# %%
keywords_ru_noun.to_csv(pathjoin(DATA_DIR, 'natasha_keywords_ru_noun.csv'))
keywords_ru_adj.to_csv(pathjoin(DATA_DIR, 'natasha_keywords_ru_adj.csv'))
keywords_ru_adv.to_csv(pathjoin(DATA_DIR, 'natasha_keywords_ru_adv.csv'))
keywords_ru_verb.to_csv(pathjoin(DATA_DIR, 'natasha_keywords_ru_verb.csv'))
