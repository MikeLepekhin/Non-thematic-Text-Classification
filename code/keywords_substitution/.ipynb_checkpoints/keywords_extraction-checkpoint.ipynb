# %%
#!pip install pymorphy2==0.8

# %%
import tensorflow as tf
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
from nltk.corpus import stopwords
import nltk
from os.path import join as pathjoin
import spacy_udpipe
import tqdm
#nltk.download('stopwords')
print(tf.__version__)
# Out:
# 2.3.0

# %%
DATA_DIR = '/home/mlepekhin/data'
MODELS_DIR = '/home/mlepekhin/models'

# %%
df_en_train = pd.read_csv(pathjoin(DATA_DIR, 'en_train'))
df_ru_train = pd.read_csv(pathjoin(DATA_DIR, 'ru_train'))

# %%
df_en_train.values.shape
# Out:
# (1264, 3)

# %%
target_names = np.unique(df_en_train.target)
print(target_names)
# Out:
# ['A1' 'A11' 'A12' 'A14' 'A16' 'A17' 'A22' 'A4' 'A7' 'A8' 'A9']

# %%
X_train_ru = df_ru_train['text'].values
y_train_ru = df_ru_train['target'].values
X_train_en = df_en_train['text'].values
y_train_en = df_en_train['target'].values

# %% [markdown]
# ### POS extraction

# %%
nlp_ru = spacy_udpipe.load("ru")
nlp_en = spacy_udpipe.load("en")

# %%
pos_list = ['ADV', 'ADJ', 'NOUN', 'VERB']

def extract_pos_dataset(X_train, model):
    result_df = {'ADV': [], 'ADJ': [], 'NOUN': [], 'VERB': []}
    #last_sentence = {'ADV': '', 'ADJ': '', 'NOUN': '', 'VERB': ''}
    
    
    for sent in tqdm.tqdm(X_train):
        doc = model(sent)
        last_sentence = {'ADV': '', 'ADJ': '', 'NOUN': '', 'VERB': ''}
        for token in doc:
            if token.pos_ in pos_list:
                last_sentence[token.pos_] += ' ' + token.text
        for pos, value in last_sentence.items():
            if len(value):
                result_df[pos].append(value)
    return result_df

# %%
ru_pos_df = extract_pos_dataset(X_train_ru, nlp_ru)
# Out:
# 100%|██████████| 1447/1447 [17:20<00:00,  1.39it/s]

# %%
en_pos_df = extract_pos_dataset(X_train_en, nlp_en)
# Out:
# 100%|██████████| 1264/1264 [19:47<00:00,  1.06it/s]

# %%
print(en_pos_df['NOUN'][500])
# Out:
#  Report Convention Note secretariat Contents Paragraphs Page Mandate Conference Parties session decision CP Group Experts Communications Convention objective preparation communications Parties -Annex Parties order objective COP annex decision CGE experience information preparation communications consideration experience meetings workshops basis agendas consultation participants Consider needs availability resources support identification barriers gaps support Consider information communications non-Annex Parties accordance guidelines preparation communications non-Annex Parties annex decision CP Review activities programmes preparation communications non-Annex view gaps recommendations activities programmes order preparation communications difficulties non-Annex Parties use guidelines annex decision CP use methodologies models recommendations improvement issues problems preparation reporting greenhouse gas inventories respect improvement data collection development emission factors activity data development methodologies view quality inventories communications greenhouse gas inventories non-Annex Parties view recommendations ways difficulties use methodologies UNFCCC guidelines inventories annex decision CP innovations reports interaction experts Parties COP session decision CP CGE objective preparation communications non-Annex Parties decision addition mandate annex decision CP CGE problems constraints preparation communications non-Annex Parties recommendations consideration bodies input draft guidelines preparation communications non-Annex Parties COP decision CP CGE workshops objective experiences coverage issues paragraph Scope report document summary issues problems constraints preparation communications preparation communications non-Annex Parties section activities programmes preparation communications non-Annex Parties section IV Section recommendations improvement process preparation communications non-Annex Parties actions bodies note information document view process preparation communications non-Annex Parties COP draft decision guidance work CGE preparation communications non-Annex Parties addition recommendations CGE report recommendations Advice view methods tools models use non-Annex Parties information document recommendations COP bilateral support programmes resources support preparation communications non-Annex Parties Organization work Pursuant decisions CP CP meetings sessions bodies workshops issues meetings consideration conclusions recommendations workshops improvement preparation communications non-Annex Parties development work plans examination information communications non-Annex Parties preparation reports consideration bodies reports meetings documents report meeting Chair report bodies sixteenth session annex document workshops CGE members support secretariat exchange experiences non-Annex Parties region preparation elements communication problems constraints issues recommendations consideration bodies problems constraints total experts non Parties experts Annex Parties representatives bilateral agencies workshops elements communication workshops inventories vulnerability adaptation assessment research observation mitigation analysis education training awareness information networking support view need information elements communication task groups GHG inventory vulnerability adaptation assessment research observation GHG mitigation analysis education training awareness information networking support task groups coordinator information communications meetings workshops CGE members use listserv secretariat views issues discharge work work secretariat support reports CGE mandate terms reference annex decision CP information compilation synthesis report communications secretariat report work bodies fifteenth session report conclusions recommendations CGE improvement preparation elements communication recommendations improvement guidelines preparation communications non-Annex Parties annex decision  ...

# %% [markdown]
# ### Keyword extraction and writing them to csv files

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import string

def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    sorted_items = sorted_items[:topn]

    score_vals = []
    feature_vals = []
    
    for idx, score in sorted_items:
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    results = {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]] = score_vals[idx]
    return results

def preprocess(text):
    lowercased = text.translate(str.maketrans("", "", string.punctuation)).lower()
    return ''.join([c for c in lowercased if not c.isdigit()])

def get_keywords_df(X_train, y_train, stop_words):
    cv = CountVectorizer(max_df=0.8, stop_words=stop_words)
    word_count_vector = cv.fit_transform(X_train)
    tfidf_transformer = TfidfTransformer(smooth_idf=True, use_idf=True)
    tfidf_transformer.fit(word_count_vector)

    topics_doc = {}
    for text, label in zip(X_train, y_train):
        if label not in topics_doc:
            topics_doc[label] = text
        else:
            topics_doc[label] += " " + text

        keywords_df = pd.DataFrame()
        feature_names = cv.get_feature_names()

    for topic_label, topic_text in topics_doc.items():
        topic_text = preprocess(topic_text)
        tf_idf_vector = tfidf_transformer.transform(cv.transform([topic_text]))
        sorted_items = sort_coo(tf_idf_vector.tocoo())
        keywords = extract_topn_from_vector(feature_names, sorted_items, 20)

        print("\n=====Doc=====")
        print(topic_text[:100])
        print("\n===Keywords===")
        for keyword in keywords:
            keywords_df = keywords_df.append({'keyword': keyword, 'topic': topic_label}, ignore_index=True)
            print(keyword, keywords[keyword])
    return keywords_df

# %%
keywords_ru_noun = get_keywords_df(ru_pos_df['NOUN'], y_train_ru, stopwords.words("russian") + ["это"])
keywords_ru_adj = get_keywords_df(ru_pos_df['ADJ'], y_train_ru, stopwords.words("russian") + ["это"])
keywords_ru_adv = get_keywords_df(ru_pos_df['ADV'], y_train_ru, stopwords.words("russian") + ["это"])
keywords_ru_verb = get_keywords_df(ru_pos_df['VERB'], y_train_ru, stopwords.words("russian") + ["это"])
# Out:
# =====Doc=====
#  оао создания комплекса мощностью млн т год директор оао компания группы председатель совета директо
#
# ===Keywords===
# года 0.312
# президент 0.22
# млрд 0.215
# году 0.17
# газа 0.131
# словам 0.127
# президента 0.121
# млн 0.121
# власти 0.116
# страны 0.111
# глава 0.11
# время 0.1
# ходе 0.098
# нефть 0.097
# долларов 0.097
# марта 0.087
# компании 0.086
# сентября 0.083
# рублей 0.079
# апреля 0.078
#
# =====Doc=====
#  ходе написания ходатайства образцу постановлений заголовка подозреваемый делу материалы дела центру
#
# ===Keywords===
# br 0.553
# лет 0.163
# людей 0.112
# время 0.111
# жизни 0.103
# отец 0.096
# смех 0.091
# люди 0.088
# жизнь 0.084
# спасибо 0.083
# человек 0.079
# книги 0.074
# году 0.072
# работа 0.063
# психологии 0.06
# человека 0.06
# год 0.059
# работы 0.058
# день 0.058
# мама 0.057
#
# =====Doc=====
#  характеристики м етодика испытаний замеров характеристика оборудования котла хема измерений котла а
#
# ===Keywords===
# исследования 0.133
# теории 0.116
# развития 0.111
# личности 0.106
# системы 0.101
# области 0.098
# др 0.091
# наука 0.087
# наук 0.085
# жизни 0.083
# основе 0.082
# работы 0.082
# образом 0.079
# науки 0.078
# данных 0.074
# время 0.074
# процессов 0.074
# рис 0.073
# языка 0.073
# колебаний 0.073
#
# =====Doc=====
#  человечество целей стремление идеалу совершенству стремление перфекционизм психики грань желание ми
#
# ===Keywords===
# года 0.19
# совещания 0.163
# деятельности 0.162
# конвенции 0.144
# государств 0.131
# сессии 0.125
# секретариат 0.123
# комитет 0.108
# стран 0.107
# разминированию 0.105
# помощи 0.101
# рамках 0.098
# секретариата 0.097
# отношении 0.095
# вопросам 0.094
# работы 0.092
# доклад 0.092
# экспертов 0.09
# осуществления 0.088
# развития 0.085
#
# =====Doc=====
#  сайдинг отделка дома сайдингом сайдинг отделки стен цоколя дома материал зданий предприятий отделка
#
# ===Keywords===
# мм 0.246
# волос 0.209
# компании 0.139
# модель 0.135
# компания 0.128
# модели 0.114
# качества 0.112
# система 0.092
# кг 0.089
# время 0.089
# материалов 0.086
# системы 0.083
# техники 0.081
# эксплуатации 0.081
# производства 0.079
# продукции 0.079
# характеристики 0.077
# работы 0.077
# использования 0.076
# мебели 0.075
#
# =====Doc=====
#  p софия ананке  ногами потолке  ноги  потолка наги  софия  ананке  окном снег br окном  углом снег
#
# ===Keywords===
# русалочка 0.173
# глаза 0.138
# сыновья 0.128
# женщина 0.117
# руки 0.115
# человек 0.114
# папаша 0.112
# письмо 0.107
# время 0.102
# сердце 0.101
# руку 0.099
# голову 0.09
# лицо 0.088
# день 0.087
# сыновей 0.086
# дело 0.08
# дверь 0.079
# лет 0.076
# голос 0.075
# доме 0.075
#
# =====Doc=====
#  окрашивание технологий университет программистка компании разработчика обеспечения плане удовлетвор
#
# ===Keywords===
# детей 0.248
# миростроительству 0.186
# человека 0.129
# развития 0.118
# года 0.111
# мира 0.108
# жизни 0.106
# страны 0.104
# стран 0.103
# миростроительства 0.096
# время 0.094
# вопрос 0.093
# государства 0.091
# секретаря 0.091
# области 0.09
# человек 0.089
# безопасности 0.089
# общества 0.086
# конфликтах 0.085
# лет 0.081
#
# =====Doc=====
#  матче дождем сил ворота гол восторга конце тайма достоинством блин пенальти сердце горя дер вратарь
#
# ===Keywords===
# фильм 0.202
# игра 0.132
# книги 0.128
# ссылок 0.12
# сюжет 0.111
# фильма 0.109
# время 0.107
# кино 0.106
# фильме 0.094
# млн 0.087
# ссылки 0.084
# день 0.084
# кафе 0.076
# gap 0.071
# кун 0.071
# интернет 0.07
# рецензия 0.07
# туалеты 0.067
# деньги 0.067
# лет 0.067
#
# =====Doc=====
#  даты мастер классов мая года регистрация участников апреля года программы фестиваля залы вал ст м е
#
# ===Keywords===
# соответствии 0.223
# статьи 0.206
# статья 0.195
# ст 0.176
# договора 0.163
# лица 0.145
# лиц 0.132
# государства 0.122
# совета 0.108
# права 0.099
# отношении 0.098
# право 0.098
# организации 0.096
# случае 0.096
# связи 0.093
# пунктом 0.087
# оборудования 0.087
# порядке 0.086
# законодательства 0.086
# лицо 0.084
#
# =====Doc=====
#  глава touchflo™ экран touchflo™ управление устройствами платформе экран доступ касанием пальца функ
#
# ===Keywords===
# почты 0.322
# эл 0.307
# экране 0.194
# коммуникаторе 0.15
# вкладке 0.143
# сети 0.142
# сообщения 0.142
# экран 0.13
# поиска 0.128
# программы 0.121
# коммуникатор 0.12
# экрана 0.116
# коммуникатора 0.113
# настройка 0.111
# настройки 0.111
# примечание 0.104
# сведения 0.102
# контакты 0.101
# кнопку 0.1
# разделе 0.099
#
# =====Doc=====
#  этиленового генеральный материнская третьем чистой третьем чистую текущего чистая известно высший а
#
# ===Keywords===
# воздушного 0.219
# предварительного 0.18
# стокгольмской 0.164
# должны 0.164
# российской 0.163
# других 0.15
# необходимо 0.132
# международного 0.116
# должна 0.113
# генерального 0.108
# стойких 0.107
# другие 0.097
# органических 0.092
# должен 0.087
# генеральной 0.084
# различных 0.081
# персональных 0.077
# письменном 0.073
# международных 0.073
# новых 0.072
#
# =====Doc=====
#  следственных вводную уголовному уголовного положено общем уголовное п должен двойном тетрадном тако
#
# ===Keywords===
# национальных 0.264
# международного 0.186
# должны 0.183
# генерального 0.177
# российской 0.135
# других 0.134
# необходимо 0.126
# высшем 0.118
# должен 0.11
# международных 0.107
# палестинских 0.094
# отдельной 0.092
# африканских 0.091
# личные 0.09
# первоначальных 0.09
# другие 0.085
# настоящей 0.085
# должно 0.082
# государственного 0.08
# физической 0.08
#
# =====Doc=====
#  раткая техническая водная езультаты ежимная водогрейного перативная режимная водогрейного п котельн
#
# ===Keywords===
# земельного 0.275
# настоящей 0.204
# российской 0.179
# налогового 0.169
# земельных 0.156
# других 0.147
# научного 0.118
# должны 0.117
# научных 0.116
# пелагических 0.113
# государственной 0.112
# необходимо 0.107
# генеральной 0.095
# настоящего 0.095
# другие 0.094
# океанологических 0.092
# насильственного 0.088
# бездомных 0.088
# индивидуального 0.088
# настоящим 0.082
#
# =====Doc=====
#  лучшему амбициозных подобное полезным человеческой навязчивой патологической данного английского уч
#
# ===Keywords===
# диссертационного 0.63
# ученой 0.38
# транспортного 0.261
# диссертационный 0.25
# демократической 0.126
# минной 0.113
# противоминной 0.107
# российской 0.074
# гражданского 0.073
# татарского 0.072
# политической 0.071
# настоящего 0.065
# генерального 0.063
# других 0.06
# транспортное 0.059
# межсессионной 0.058
# должны 0.057
# инвестиционных 0.055
# литературном 0.055
# ученых 0.055
#
# =====Doc=====
#  виниловый виниловый современный строительный жилых коммерческих торговых привлекательный стильный в
#
# ===Keywords===
# российской 0.203
# государственного 0.154
# других 0.128
# го 0.124
# должны 0.123
# необходимо 0.116
# другие 0.108
# нужно 0.106
# настоящего 0.098
# продовольственной 0.09
# социокультурных 0.086
# должен 0.086
# англ 0.082
# различных 0.082
# котоpый 0.082
# налоговой 0.081
# профессионального 0.075
# антропологического 0.075
# фискального 0.072
# самое 0.072
#
# =====Doc=====
#  сестринские  новый нетрудно городские камонской циртские простыми бодрым каменные мостовой тяжелыми
#
# ===Keywords===
# почтовой 0.66
# почтовых 0.246
# российской 0.166
# неблагоприятных 0.122
# религиозной 0.12
# национальных 0.108
# муниципальных 0.106
# особенной 0.1
# федеральным 0.086
# денежных 0.085
# местного 0.082
# религиозных 0.08
# соответствующей 0.079
# настоящего 0.076
# нерозданных 0.075
# других 0.073
# строгого 0.072
# почтовые 0.071
# федеральной 0.07
# государственной 0.068
#
# =====Doc=====
#  африканских технологический целеустремленная молодая программного компьютерным крупнейшая телекомму
#
# ===Keywords===
# муниципального 0.274
# должны 0.164
# взрывоопасных 0.155
# статистической 0.134
# семейских 0.127
# христианских 0.115
# других 0.112
# технического 0.11
# местного 0.107
# российской 0.106
# нужно 0.099
# взрывоопасной 0.094
# необходимо 0.092
# настоящего 0.09
# космическом 0.082
# римской 0.079
# большой 0.079
# другие 0.078
# данной 0.078
# различных 0.076
#
# =====Doc=====
#  безутешный вчерашнем проливным первый синие первого правый доволен голевые подобных синих красных о
#
# ===Keywords===
# минимальных 0.409
# административного 0.159
# должностных 0.12
# электронной 0.119
# ежегодной 0.114
# других 0.114
# юридических 0.106
# российской 0.103
# новые 0.101
# должен 0.094
# другие 0.092
# настоящей 0.09
# проектно 0.09
# авиационной 0.09
# новый 0.087
# самовольное 0.078
# молодежных 0.073
# должна 0.073
# нужно 0.073
# сперанского 0.073
#
# =====Doc=====
#  центральном рымский октябрьская взрослые взрослые международному взрослые педагогическую художестве
#
# ===Keywords===
# российской 0.516
# главного 0.302
# генеральной 0.29
# федерального 0.173
# генерального 0.151
# должностными 0.135
# должностные 0.134
# настоящей 0.129
# прокурорского 0.124
# должностных 0.117
# шумового 0.108
# шумовых 0.103
# транспортных 0.092
# должны 0.089
# маховое 0.088
# ое 0.083
# государственных 0.082
# государственного 0.077
# соответствующих 0.074
# других 0.07
#
# =====Doc=====
#  начальный сенсорное начальный начальном следующие главная избранные начального горизонтальной верти
#
# ===Keywords===
# синий 0.209
# впитывающее 0.192
# почтовой 0.172
# почтовых 0.169
# меньшей 0.151
# национальной 0.139
# русской 0.129
# эластичные 0.128
# почтовые 0.121
# учетной 0.119
# кристаллического 0.118
# человеческих 0.109
# фиолетового 0.108
# электронодонорный 0.104
# красный 0.102
# боковые 0.102
# фондовой 0.098
# почтового 0.097
# начальном 0.09
# фиолетовый 0.087
# =====Doc=====
#  ранее ранее сильно больше ранее сегодня сегодня более  ранее  также также так недавно  действительн
#
# ===Keywords===
# также 0.395
# очень 0.265
# например 0.256
# однако 0.216
# затем 0.17
# поэтому 0.165
# включая 0.163
# менее 0.147
# вместе 0.142
# сегодня 0.138
# наиболее 0.122
# далее 0.122
# вопервых 0.119
# почему 0.109
# особенно 0.109
# полностью 0.109
# обычно 0.096
# возможно 0.094
# вообще 0.093
# попрежнему 0.093
#
# =====Doc=====
#  потом потом потом неминуемо потому обычно длиннее иногда например еще там обычно еще гдето такто  д
#
# ===Keywords===
# очень 0.358
# также 0.278
# затем 0.244
# например 0.228
# однако 0.194
# поэтому 0.191
# часто 0.167
# наиболее 0.139
# полностью 0.131
# ранее 0.12
# сегодня 0.116
# вместе 0.112
# аналогично 0.108
# назад 0.105
# действительно 0.105
# точно 0.102
# автоматически 0.1
# слишком 0.099
# немного 0.097
# включая 0.096
#
# =====Doc=====
#  опливо еречень режимно наиболее очень менее когда более менее более снаружи опливо где где где rо г
#
# ===Keywords===
# унамуно 0.323
# также 0.281
# затем 0.226
# очень 0.214
# однако 0.212
# например 0.199
# далее 0.14
# сегодня 0.138
# вниз 0.134
# почему 0.133
# наиболее 0.13
# менее 0.128
# выше 0.127
# попрежнему 0.123
# включая 0.12
# рубяще 0.113
# вверх 0.11
# снова 0.106
# поэтому 0.106
# назад 0.104
#
# =====Doc=====
#  конечно однако всегда как довольно легко тогда неслучайно много однако положительно теперь как выше
#
# ===Keywords===
# также 0.463
# однако 0.231
# поэтому 0.227
# очень 0.187
# особенно 0.178
# попрежнему 0.171
# например 0.169
# сегодня 0.155
# затем 0.143
# включая 0.13
# полностью 0.129
# вместе 0.12
# дальше 0.117
# вполне 0.113
# несмотря 0.104
# автоматически 0.101
# вновь 0.1
# вопервых 0.1
# часто 0.099
# весьма 0.097
#
# =====Doc=====
#  можно достаточно немного дома вместе дома можно весьма хорошо вместе особенно дома очень значительн
#
# ===Keywords===
# также 0.309
# очень 0.301
# сегодня 0.231
# поэтому 0.229
# однако 0.209
# затем 0.172
# особенно 0.155
# вместе 0.155
# наиболее 0.143
# например 0.139
# далее 0.137
# вообще 0.137
# действительно 0.125
# пока 0.106
# весьма 0.105
# почему 0.103
# вопервых 0.103
# следовательно 0.102
# совершенно 0.102
# назад 0.1
#
# =====Doc=====
#  весело грустно весело вдвоем  вращательно вращательно небесно гравитационно менее гравитационно  ве
#
# ===Keywords===
# очень 0.249
# также 0.239
# почему 0.181
# менее 0.164
# однако 0.161
# сегодня 0.146
# например 0.145
# тотчас 0.144
# поэтому 0.144
# выше 0.137
# включая 0.132
# практически 0.132
# полностью 0.131
# вместе 0.13
# наиболее 0.128
# следовательно 0.107
# снова 0.106
# максимально 0.104
# внутри 0.104
# несмотря 0.101
#
# =====Doc=====
#  быстро серьезно более так сегодня полностью совсем так также предположительно однако вероятно гораз
#
# ===Keywords===
# очень 0.329
# также 0.282
# однако 0.225
# например 0.219
# поэтому 0.215
# затем 0.209
# сегодня 0.176
# менее 0.139
# особенно 0.131
# наиболее 0.129
# далее 0.127
# совершенно 0.117
# вместе 0.116
# ещё 0.114
# весьма 0.11
# сразу 0.108
# практически 0.106
# вопервых 0.104
# почему 0.098
# вообще 0.094
#
# =====Doc=====
#  очно так заочно так более менее д менее более дополнительно менее  четырежды позднее подряд трижды
#
# ===Keywords===
# также 0.393
# включая 0.282
# например 0.228
# вправе 0.218
# поэтому 0.212
# однако 0.209
# очень 0.198
# менее 0.183
# полностью 0.153
# особенно 0.147
# вдобавок 0.134
# наиболее 0.131
# далее 0.125
# сегодня 0.108
# вопервых 0.099
# самостоятельно 0.096
# вместе 0.089
# значительно 0.089
# настоятельно 0.087
# впредь 0.081
#
# =====Doc=====
#  сегодня более  еще пока поэтому рядом заодно специально теперь уже как поэтому  юморески чрезвычайн
#
# ===Keywords===
# также 0.364
# поэтому 0.233
# очень 0.203
# назад 0.193
# подробнее 0.189
# однако 0.167
# ранее 0.155
# возможно 0.144
# сегодня 0.13
# например 0.13
# вероятно 0.119
# менее 0.114
# действительно 0.114
# влево 0.113
# почему 0.108
# вполне 0.105
# пока 0.1
# весьма 0.098
# вместе 0.097
# вправо 0.097
#
# =====Doc=====
#  также  вчера серьезно ранее также рано поздно существенно более слева включая однако также ранее та
#
# ===Keywords===
# включая 0.324
# также 0.261
# очень 0.247
# однако 0.178
# ассоциативно 0.166
# сегодня 0.154
# прежде 0.144
# вместе 0.142
# попрежнему 0.137
# вправе 0.13
# особенно 0.127
# прямо 0.124
# сразу 0.118
# свободно 0.116
# совершенно 0.114
# ранее 0.11
# насколько 0.109
# ещё 0.106
# впоследствии 0.104
# ясно 0.098
#
# =====Doc=====
#  отказывается сообщил получило получила увеличилась стало удовлетворил нижнекамскнефтехим рассматрив
#
# ===Keywords===
# нажмите 0.552
# объединенных 0.221
# является 0.164
# заявил 0.132
# могут 0.117
# правило 0.114
# см 0.101
# выберите 0.098
# сказал 0.094
# следует 0.094
# имеет 0.093
# говорит 0.087
# могли 0.082
# сделать 0.079
# хотел 0.076
# являются 0.074
# использовать 0.074
# позволяет 0.072
# руководящих 0.07
# обеспечить 0.069
#
# =====Doc=====
#  сделать есть рассмотрев установил закончим изложенного руководствуясь регламентируют ходатайствую п
#
# ===Keywords===
# вооруженных 0.458
# объединенных 0.307
# говорит 0.145
# является 0.145
# хотел 0.136
# включенных 0.114
# занять 0.088
# могут 0.085
# приглашаю 0.083
# являются 0.082
# следует 0.08
# затронутых 0.079
# выступить 0.078
# сказал 0.078
# позволяет 0.077
# включенными 0.073
# имеет 0.071
# выразить 0.068
# сделать 0.067
# касается 0.066
#
# =====Doc=====
#  т налаживаемого т з выработанную отпущенную ротокол т установленного используемых настоящий содержи
#
# ===Keywords===
# правило 0.275
# могут 0.211
# является 0.2
# объединенных 0.172
# те 0.146
# см 0.141
# имеет 0.126
# осужденного 0.112
# принимает 0.109
# являются 0.106
# окружающей 0.088
# следует 0.085
# раздел 0.081
# уведомляет 0.081
# применяются 0.081
# принять 0.077
# уполномочивается 0.076
# говорит 0.076
# представляет 0.071
# можете 0.07
#
# =====Doc=====
#  заставляло меняться эволюционировать достигать называют бывает определить сделать совершенным стано
#
# ===Keywords===
# рекомендовано 0.351
# пострадавшим 0.332
# рекомендовал 0.213
# объединенных 0.204
# руководящих 0.143
# затронутых 0.131
# создан 0.128
# является 0.113
# руководящие 0.084
# могут 0.083
# невзорвавшихся 0.081
# следует 0.079
# ввёл 0.078
# имеет 0.076
# предложил 0.072
# условлено 0.071
# участвовавших 0.07
# отметил 0.069
# обсудил 0.067
# стал 0.066
#
# =====Doc=====
#  предназначен применять придает обеспечивает отличается может справиться делает обладает делают рест
#
# ===Keywords===
# является 0.265
# могут 0.15
# позволяет 0.142
# имеет 0.133
# хотел 0.119
# являются 0.118
# объединенных 0.117
# следует 0.115
# сказал 0.113
# сделать 0.108
# можем 0.108
# сказать 0.103
# использовать 0.096
# можете 0.089
# мог 0.086
# означает 0.086
# заявил 0.081
# имеют 0.078
# думаю 0.077
# становится 0.076
#
# =====Doc=====
#  знает знает идет живут смеются идет обнажая следить  выступили дали расположились сказали ублажая о
#
# ===Keywords===
# развивающихся 0.181
# является 0.163
# рассеянного 0.154
# сказал 0.136
# могут 0.13
# предусмотренного 0.108
# спросил 0.102
# существует 0.091
# совершенное 0.091
# осужденного 0.089
# существующих 0.085
# являются 0.081
# осел 0.08
# превышать 0.079
# развивающимися 0.079
# думаю 0.079
# включенных 0.076
# стали 0.074
# назначается 0.071
# имеют 0.071
#
# =====Doc=====
#  забудьте здравствует ведущей мечтает усовершенствовать планирует поступить устанавливает сделанное
#
# ===Keywords===
# лешти 0.255
# объединенных 0.248
# является 0.244
# см 0.167
# могут 0.16
# говорит 0.141
# сказал 0.137
# имеет 0.137
# являются 0.104
# сказала 0.1
# хотел 0.099
# следует 0.092
# стоит 0.084
# имеют 0.081
# обеспечить 0.075
# стали 0.075
# существует 0.074
# осуществляется 0.071
# сделать 0.071
# стал 0.07
#
# =====Doc=====
#  завершившемся болел сказать влетел прыгал отыгрались произнес забил разорвалось угадав отбил умер с
#
# ===Keywords===
# могут 0.149
# объединенных 0.145
# можете 0.13
# находящихся 0.116
# следует 0.115
# развивающихся 0.114
# сказала 0.106
# запрещены 0.098
# оплатить 0.096
# приветствуются 0.091
# имеет 0.089
# является 0.089
# принимается 0.088
# говорит 0.085
# имеют 0.079
# могу 0.078
# обеспечить 0.077
# предусмотренные 0.076
# получить 0.074
# осуществляется 0.074
#
# =====Doc=====
#  пройдут ул открыты обратите имеют провести перейти предложить скачать скачать осуществляющие имеющи
#
# ===Keywords===
# объединенных 0.427
# приравненных 0.188
# влечет 0.172
# могут 0.159
# специализированных 0.155
# принимает 0.139
# указанных 0.138
# нажмите 0.133
# имеет 0.133
# организуют 0.114
# является 0.111
# установленном 0.105
# предусмотренных 0.103
# см 0.089
# действующего 0.088
# являются 0.085
# населяет 0.084
# обеспечивает 0.081
# организует 0.08
# издаваемых 0.078
#
# =====Doc=====
#  обеспечивает обеспечивает используемым избранные есть отображаются выдвинуть изменится пропадут пок
#
# ===Keywords===
# нажмите 0.857
# выберите 0.138
# определяющий 0.106
# открыть 0.095
# могут 0.095
# откройте 0.093
# см 0.093
# позвонить 0.085
# введите 0.08
# просмотреть 0.074
# добавить 0.074
# выбрать 0.07
# содержит 0.07
# наносят 0.068
# удалить 0.065
# хотите 0.064
# избранные 0.062
# ввести 0.055
# отправить 0.054
# определяющего 0.05

# %%
keywords_en_noun = get_keywords_df(en_pos_df['NOUN'], y_train_en, stopwords.words("english"))
keywords_en_adj = get_keywords_df(en_pos_df['ADJ'], y_train_en, stopwords.words("english"))
keywords_en_adv = get_keywords_df(en_pos_df['ADV'], y_train_en, stopwords.words("english"))
keywords_en_verb = get_keywords_df(en_pos_df['VERB'], y_train_en, stopwords.words("english"))
# Out:
# =====Doc=====
#  indianapolis april disruption travel chaos cities activity air navigation agency air traffic delays
#
# ===Keywords===
# disarmament 0.148
# report 0.143
# demobilization 0.129
# year 0.127
# programme 0.126
# club 0.125
# budget 0.12
# monuc 0.119
# committee 0.117
# government 0.115
# staff 0.111
# situation 0.105
# forces 0.102
# biennium 0.101
# police 0.099
# meeting 0.098
# people 0.096
# sex 0.096
# parties 0.096
# income 0.093
#
# =====Doc=====
#  yaws spoof interview state democracy war terror oil stuff comments end withdrawal day newspapers jo
#
# ===Keywords===
# reconciliation 0.191
# people 0.16
# countries 0.147
# government 0.143
# development 0.14
# world 0.125
# society 0.12
# children 0.11
# women 0.104
# country 0.102
# data 0.102
# weapons 0.102
# state 0.096
# security 0.095
# work 0.09
# law 0.088
# community 0.088
# education 0.086
# justice 0.085
# information 0.085
#
# =====Doc=====
#  enquiry advice telephone email advice process requirements quote enquiry quotes enquiries day artwo
#
# ===Keywords===
# cialis 0.27
# viagra 0.185
# th 0.179
# business 0.141
# service 0.141
# information 0.131
# product 0.129
# products 0.127
# writing 0.125
# customers 0.125
# company 0.11
# levitra 0.107
# services 0.099
# essay 0.098
# people 0.092
# pm 0.091
# time 0.09
# work 0.089
# dissertation 0.087
# customer 0.086
#
# =====Doc=====
#  meetings programs companies world years clients research paper writing service needs students day h
#
# ===Keywords===
# products 0.381
# loan 0.36
# payday 0.266
# prices 0.232
# show 0.226
# loans 0.208
# credit 0.192
# range 0.18
# football 0.17
# mortgage 0.148
# cialis 0.138
# cash 0.106
# rate 0.105
# prescription 0.093
# th 0.092
# viagra 0.083
# time 0.071
# police 0.069
# kids 0.068
# bank 0.068
#
# =====Doc=====
#  newsletter stocks exchange funds etfs call options newsletter times week email archive newsletters
#
# ===Keywords===
# tap 0.389
# device 0.342
# screen 0.337
# email 0.239
# tab 0.189
# settings 0.164
# phone 0.159
# call 0.144
# message 0.141
# contact 0.138
# file 0.108
# video 0.103
# contacts 0.103
# messages 0.103
# card 0.099
# text 0.098
# information 0.095
# search 0.094
# details 0.082
# list 0.082
#
# =====Doc=====
#  goddess hypothesis deity development pagan religions idea religion support classicists century hist
#
# ===Keywords===
# secretariat 0.248
# parties 0.232
# convention 0.215
# meeting 0.21
# committee 0.202
# article 0.156
# conference 0.137
# rights 0.109
# falls 0.107
# countries 0.1
# meetings 0.099
# assistance 0.095
# report 0.092
# sce 0.089
# draft 0.089
# rules 0.088
# implementation 0.086
# information 0.086
# work 0.084
# development 0.084
#
# =====Doc=====
#  technology role way celebrate life events artefacts messages photos artefacts guest books heirloom
#
# ===Keywords===
# fault 0.367
# tolerance 0.22
# system 0.2
# application 0.171
# faults 0.14
# image 0.138
# software 0.134
# data 0.133
# recovery 0.128
# time 0.118
# node 0.107
# function 0.106
# error 0.104
# case 0.101
# failure 0.098
# model 0.098
# code 0.095
# transform 0.093
# signal 0.09
# task 0.085
#
# =====Doc=====
#  pp spring project rain cloud improvement hours bus weather start minute food gear place conditions
#
# ===Keywords===
# people 0.207
# time 0.19
# years 0.172
# world 0.135
# love 0.129
# day 0.126
# agreement 0.125
# life 0.119
# church 0.117
# things 0.115
# book 0.113
# lot 0.112
# work 0.111
# th 0.109
# way 0.103
# year 0.1
# countries 0.086
# brain 0.084
# passage 0.083
# community 0.08
#
# =====Doc=====
#  shortlist dream tease review rom mutants satire murder mystery gruelling flashback war independence
#
# ===Keywords===
# playstation 0.158
# film 0.152
# artist 0.146
# exhibition 0.137
# work 0.136
# game 0.136
# time 0.125
# music 0.118
# art 0.115
# console 0.111
# show 0.106
# home 0.105
# th 0.101
# shoes 0.099
# gallery 0.09
# space 0.089
# life 0.088
# speaker 0.085
# family 0.085
# review 0.085
#
# =====Doc=====
#  increases date discretion government time contributions contributions party behalf net rate income
#
# ===Keywords===
# article 0.316
# paragraph 0.238
# person 0.217
# order 0.198
# building 0.15
# court 0.141
# contractor 0.139
# department 0.122
# parties 0.117
# provision 0.112
# company 0.112
# party 0.112
# convention 0.112
# conditions 0.107
# offence 0.105
# persons 0.104
# notice 0.1
# date 0.098
# officials 0.095
# application 0.094
#
# =====Doc=====
#  days galaxy sir bridge ass concern replicators form ones grasp psyche images bugs heaven sake head
#
# ===Keywords===
# man 0.229
# eyes 0.158
# father 0.152
# door 0.131
# water 0.131
# head 0.129
# mother 0.126
# hand 0.123
# time 0.121
# day 0.12
# room 0.117
# house 0.115
# one 0.108
# face 0.107
# woman 0.105
# heart 0.102
# men 0.102
# sea 0.1
# hands 0.1
# morning 0.099
#
# =====Doc=====
#  many major european volcanic european several many concerned massive executive natural complete nat
#
# ===Keywords===
# financial 0.203
# many 0.196
# nuclear 0.181
# new 0.162
# first 0.152
# good 0.135
# important 0.131
# digital 0.127
# great 0.122
# general 0.114
# executive 0.105
# several 0.105
# available 0.104
# current 0.101
# best 0.097
# free 0.097
# local 0.095
# international 0.094
# able 0.094
# german 0.092
#
# =====Doc=====
#  succinct morbid usual interesting short sovereign democratic independent remote likely independent
#
# ===Keywords===
# first 0.176
# new 0.171
# international 0.168
# nuclear 0.166
# human 0.152
# political 0.15
# national 0.139
# many 0.126
# quantum 0.126
# present 0.125
# good 0.121
# little 0.118
# possible 0.117
# economic 0.116
# great 0.115
# important 0.109
# particular 0.106
# local 0.105
# high 0.103
# last 0.102
#
# =====Doc=====
#  free suitable costeffective immediate same possible finished prior full final highest welcome  amaz
#
# ===Keywords===
# good 0.212
# new 0.209
# many 0.176
# public 0.16
# sustainable 0.154
# financial 0.151
# local 0.144
# international 0.141
# statistical 0.133
# first 0.127
# national 0.122
# social 0.12
# great 0.12
# outer 0.118
# available 0.117
# important 0.106
# little 0.101
# old 0.101
# different 0.098
# last 0.095
#
# =====Doc=====
#  corporate incentive largest more professional custom international extraordinary largest best great
#
# ===Keywords===
# available 0.588
# scottish 0.224
# executive 0.198
# free 0.185
# general 0.155
# mobile 0.142
# new 0.118
# many 0.103
# football 0.089
# great 0.087
# different 0.087
# private 0.086
# democratic 0.083
# first 0.082
# cheap 0.081
# local 0.079
# foreign 0.075
# online 0.074
# important 0.074
# leisurewear 0.072
#
# =====Doc=====
#  covered multiple online recent new confident particular more several same most few few live able li
#
# ===Keywords===
# iranian 0.312
# new 0.202
# many 0.164
# free 0.157
# prime 0.151
# little 0.131
# first 0.13
# good 0.127
# mobile 0.117
# bad 0.113
# international 0.113
# available 0.111
# old 0.107
# military 0.103
# large 0.102
# important 0.099
# last 0.097
# great 0.095
# several 0.09
# much 0.089
#
# =====Doc=====
#  great great singular monotheistic female prior polytheistic early th various various religious such
#
# ===Keywords===
# international 0.225
# new 0.204
# nuclear 0.201
# first 0.199
# second 0.16
# many 0.158
# relevant 0.141
# good 0.135
# american 0.13
# human 0.12
# military 0.111
# great 0.101
# political 0.098
# different 0.097
# th 0.096
# national 0.095
# available 0.091
# important 0.09
# public 0.089
# intersessional 0.087
#
# =====Doc=====
#  major modern digital such digital traditional such physical useful digital major present major outl
#
# ===Keywords===
# dependable 0.25
# local 0.166
# possible 0.158
# available 0.156
# main 0.146
# redundant 0.14
# user 0.139
# new 0.139
# syntactical 0.137
# different 0.136
# current 0.13
# th 0.127
# functional 0.126
# int 0.124
# first 0.12
# important 0.119
# parallel 0.112
# critical 0.111
# single 0.108
# global 0.107
#
# =====Doc=====
#  typical british low sunny pleasant same poor frantic last hot sheer next last long flat straight pa
#
# ===Keywords===
# terrorist 0.244
# international 0.236
# biological 0.143
# adolescent 0.139
# cuban 0.139
# new 0.137
# many 0.131
# first 0.129
# large 0.126
# good 0.124
# appropriate 0.116
# foreign 0.111
# old 0.109
# sudanese 0.105
# mental 0.105
# professional 0.104
# medical 0.104
# sexual 0.103
# great 0.101
# prefabricated 0.098
#
# =====Doc=====
#  hot narrative beautiful nightmarish algerian early sexual damp antinaturalist reducible illicit you
#
# ===Keywords===
# little 0.248
# modelling 0.221
# full 0.169
# good 0.164
# great 0.16
# able 0.151
# computational 0.14
# new 0.138
# real 0.135
# last 0.135
# old 0.131
# national 0.13
# final 0.13
# specific 0.126
# different 0.125
# big 0.124
# social 0.121
# black 0.115
# simple 0.114
# many 0.114
#
# =====Doc=====
#  further personal third basic applicable applicable gross  online other online such additional like
#
# ===Keywords===
# international 0.255
# necessary 0.175
# relevant 0.172
# outer 0.167
# georgian 0.154
# enforced 0.152
# antiangiogenic 0.152
# human 0.148
# new 0.146
# concerned 0.14
# disappeared 0.14
# nuclear 0.134
# national 0.131
# appropriate 0.131
# local 0.128
# first 0.127
# current 0.126
# particular 0.123
# full 0.111
# legal 0.109
#
# =====Doc=====
#  few fine much human real good human nervous command certain unharm long deep metallic left right ma
#
# ===Keywords===
# national 0.522
# political 0.203
# international 0.167
# financial 0.166
# many 0.153
# humanitarian 0.153
# generic 0.152
# human 0.142
# technical 0.125
# great 0.121
# social 0.114
# important 0.109
# initial 0.108
# nuclear 0.095
# new 0.09
# online 0.089
# different 0.087
# long 0.087
# first 0.084
# various 0.083
# =====Doc=====
#  additionally well then also also indoors down not further pretty just when easily  then better so r
#
# ===Keywords===
# also 0.373
# back 0.245
# well 0.242
# really 0.18
# even 0.177
# still 0.163
# much 0.162
# never 0.16
# least 0.147
# therefore 0.142
# together 0.142
# first 0.139
# however 0.125
# almost 0.124
# around 0.119
# always 0.116
# away 0.115
# online 0.115
# especially 0.114
# perhaps 0.111
#
# =====Doc=====
#  very as well now so on even just less naturally basically so furthermore bitterly surely already wh
#
# ===Keywords===
# also 0.499
# well 0.229
# even 0.212
# back 0.154
# therefore 0.15
# still 0.149
# however 0.142
# often 0.141
# first 0.139
# already 0.138
# really 0.134
# actually 0.128
# never 0.112
# always 0.108
# much 0.108
# automatically 0.106
# finally 0.106
# course 0.103
# clearly 0.1
# together 0.1
#
# =====Doc=====
#  usually always most usually however where when  easily also very always only all  how now just also
#
# ===Keywords===
# also 0.371
# even 0.253
# back 0.207
# however 0.2
# still 0.19
# well 0.185
# actually 0.181
# away 0.161
# always 0.144
# really 0.143
# often 0.14
# far 0.138
# almost 0.133
# never 0.133
# soon 0.128
# much 0.128
# simply 0.119
# ever 0.118
# first 0.117
# long 0.11
#
# =====Doc=====
#  no matter when recently away just just so all absolutely when only when here now online why clearly
#
# ===Keywords===
# also 0.347
# even 0.285
# never 0.204
# away 0.183
# still 0.175
# well 0.175
# really 0.158
# often 0.154
# always 0.15
# back 0.133
# actually 0.127
# first 0.122
# however 0.121
# right 0.121
# especially 0.12
# soon 0.118
# quite 0.111
# sometimes 0.11
# together 0.107
# otherwise 0.105
#
# =====Doc=====
#  always most however never very about then historically typically just so still already automaticall
#
# ===Keywords===
# also 0.395
# even 0.241
# well 0.232
# however 0.224
# therefore 0.207
# often 0.166
# back 0.163
# still 0.151
# besides 0.147
# never 0.144
# first 0.143
# finally 0.138
# otherwise 0.136
# thus 0.127
# later 0.123
# much 0.123
# together 0.121
# always 0.121
# least 0.106
# longer 0.106
#
# =====Doc=====
#  first subsequently widely first when far further back only after further therefore also once forwar
#
# ===Keywords===
# also 0.347
# well 0.231
# back 0.226
# even 0.214
# still 0.185
# online 0.178
# never 0.175
# however 0.172
# actually 0.169
# really 0.167
# away 0.167
# much 0.157
# around 0.155
# ago 0.15
# already 0.124
# far 0.123
# instead 0.114
# right 0.11
# ever 0.11
# always 0.099
#
# =====Doc=====
#  increasingly now how where enough  so much really here here up so when now surely as far actually e
#
# ===Keywords===
# well 0.396
# also 0.389
# even 0.231
# forth 0.211
# however 0.205
# customarily 0.154
# additionally 0.151
# thus 0.131
# therefore 0.119
# still 0.116
# mostly 0.112
# otherwise 0.11
# especially 0.109
# simply 0.101
# first 0.098
# pursuant 0.093
# never 0.093
# much 0.093
# really 0.092
# usually 0.09
#
# =====Doc=====
#  late just soon increasingly home there abruptly steeper ahead soon wide almost somewhat generally t
#
# ===Keywords===
# also 0.42
# online 0.267
# well 0.263
# even 0.218
# however 0.187
# certainly 0.174
# back 0.169
# actually 0.13
# much 0.13
# still 0.127
# really 0.123
# already 0.112
# almost 0.11
# less 0.108
# soon 0.108
# usually 0.105
# particularly 0.105
# first 0.104
# currently 0.103
# often 0.101
#
# =====Doc=====
#  not less however too ironically once again at least most straightforwardly now together tellingly i
#
# ===Keywords===
# also 0.364
# even 0.254
# well 0.208
# really 0.181
# actually 0.179
# still 0.17
# however 0.165
# back 0.161
# together 0.159
# therefore 0.149
# usually 0.138
# rather 0.13
# simply 0.13
# often 0.129
# certainly 0.127
# thus 0.125
# currently 0.122
# sometimes 0.121
# first 0.118
# always 0.115
#
# =====Doc=====
#  however  accordingly so far as so far separately also otherwise on otherwise otherwise supply other
#
# ===Keywords===
# also 0.372
# even 0.242
# however 0.238
# well 0.234
# back 0.231
# away 0.179
# much 0.176
# never 0.152
# still 0.148
# environmentally 0.146
# otherwise 0.134
# always 0.131
# far 0.13
# yet 0.115
# particularly 0.113
# first 0.112
# less 0.112
# together 0.107
# often 0.101
# least 0.1
#
# =====Doc=====
#  ago far far away how so physically about mentally even really all girly thoughtfully just where jus
#
# ===Keywords===
# also 0.432
# well 0.242
# even 0.235
# however 0.177
# still 0.163
# back 0.158
# therefore 0.143
# longer 0.139
# almost 0.119
# thus 0.118
# often 0.117
# ever 0.108
# already 0.106
# sometimes 0.106
# away 0.104
# never 0.103
# furthermore 0.102
# together 0.102
# really 0.101
# visually 0.1
#
# =====Doc=====
#  continues cause following stated continue itravelinsured assisting troubled affected received stuck
#
# ===Keywords===
# said 0.416
# including 0.153
# continued 0.117
# approved 0.11
# told 0.105
# continue 0.104
# given 0.102
# see 0.1
# used 0.093
# reported 0.093
# agreed 0.093
# following 0.093
# provide 0.092
# ensure 0.09
# stated 0.089
# says 0.088
# according 0.087
# held 0.081
# discuss 0.08
# need 0.077
#
# =====Doc=====
#  signs touching let talk take start saying aims bring mean consider have want improve come runs trai
#
# ===Keywords===
# said 0.175
# made 0.156
# think 0.149
# make 0.141
# take 0.134
# see 0.129
# including 0.128
# need 0.127
# working 0.122
# know 0.122
# say 0.119
# based 0.118
# like 0.117
# get 0.107
# believe 0.101
# ensure 0.1
# thank 0.1
# want 0.097
# provide 0.096
# put 0.096
#
# =====Doc=====
#  arrive offered meet depending provide dealt produce carried using made checked approved goes ensure
#
# ===Keywords===
# posted 0.308
# buy 0.198
# help 0.176
# find 0.148
# used 0.142
# need 0.137
# learning 0.125
# use 0.124
# get 0.123
# make 0.121
# based 0.118
# take 0.118
# provide 0.118
# including 0.116
# work 0.11
# know 0.107
# using 0.102
# says 0.097
# read 0.095
# offers 0.094
#
# =====Doc=====
#  pay specializes prefer created serve need attended blown developed delivered rocked has want pay do
#
# ===Keywords===
# starting 0.518
# posted 0.257
# buy 0.224
# get 0.207
# clomid 0.191
# training 0.173
# pay 0.133
# need 0.12
# said 0.111
# make 0.109
# used 0.097
# take 0.096
# want 0.094
# find 0.087
# loans 0.082
# see 0.08
# help 0.075
# using 0.074
# know 0.072
# going 0.071
#
# =====Doc=====
#  highlights trades utilizing traded published disseminated ensure going miss log click see is provid
#
# ===Keywords===
# tap 0.371
# select 0.309
# see 0.25
# use 0.191
# open 0.182
# add 0.179
# using 0.162
# enter 0.159
# want 0.156
# set 0.144
# click 0.142
# send 0.129
# view 0.128
# need 0.118
# make 0.111
# search 0.11
# get 0.105
# change 0.1
# slide 0.094
# turn 0.094
#
# =====Doc=====
#  is worshipped proposed relating ancient achieved began postulate applying propagated has adopted pr
#
# ===Keywords===
# recommended 0.19
# made 0.189
# including 0.175
# following 0.163
# agreed 0.137
# lodged 0.127
# consider 0.122
# contained 0.116
# called 0.113
# held 0.113
# established 0.112
# noted 0.111
# developing 0.111
# considered 0.104
# provide 0.102
# became 0.1
# provided 0.1
# based 0.099
# adopted 0.098
# prepared 0.092
#
# =====Doc=====
#  plays prepare reflect stand cherished considering crafted provides understanding evolving produce u
#
# ===Keywords===
# distributed 0.264
# used 0.232
# described 0.214
# based 0.198
# called 0.177
# see 0.171
# defined 0.164
# using 0.16
# figure 0.152
# following 0.126
# given 0.126
# follows 0.122
# means 0.107
# stylized 0.107
# known 0.102
# mentioned 0.102
# executed 0.094
# introduced 0.092
# use 0.092
# allows 0.091
#
# =====Doc=====
#  departing expected arriving got found improved buying took based hit starting bring reached headed
#
# ===Keywords===
# know 0.207
# think 0.206
# go 0.201
# get 0.191
# said 0.189
# got 0.188
# see 0.168
# going 0.166
# went 0.157
# started 0.14
# came 0.135
# want 0.134
# wanted 0.133
# put 0.129
# like 0.123
# thought 0.122
# make 0.12
# take 0.118
# say 0.113
# used 0.11
#
# =====Doc=====
#  unfolded perplexing populated allegory published raising changed turned deemed left shortlisted emb
#
# ===Keywords===
# want 0.165
# see 0.155
# posted 0.153
# get 0.151
# use 0.139
# going 0.12
# need 0.113
# makes 0.11
# made 0.108
# found 0.105
# make 0.102
# got 0.099
# say 0.099
# shoes 0.097
# miss 0.096
# look 0.095
# ask 0.094
# comes 0.092
# works 0.089
# takes 0.089
#
# =====Doc=====
#  announced make paid paid paid providing meet set paid paid means entitled claim  apply run racing p
#
# ===Keywords===
# listed 0.269
# made 0.208
# apply 0.205
# entitled 0.182
# specified 0.179
# enforced 0.16
# referred 0.151
# paid 0.138
# provided 0.135
# appointed 0.135
# required 0.128
# including 0.124
# make 0.121
# authorised 0.12
# granted 0.115
# take 0.111
# applies 0.11
# ensure 0.109
# provide 0.107
# given 0.106
#
# =====Doc=====
#  doing said walked touch asked tried have said tried prompted showing said shaking had put convince
#
# ===Keywords===
# said 0.512
# came 0.184
# went 0.166
# go 0.14
# looked 0.14
# saw 0.14
# come 0.138
# see 0.137
# seemed 0.135
# know 0.123
# thought 0.122
# asked 0.118
# cried 0.113
# began 0.113
# made 0.108
# felt 0.105
# knew 0.099
# left 0.096
# stood 0.096
# heard 0.094

# %%
keywords_en_noun.head()
# Out:
#           keyword topic
# 0     disarmament    A8
# 1          report    A8
# 2  demobilization    A8
# 3            year    A8
# 4       programme    A8

# %%
keywords_ru_noun.to_csv(pathjoin(DATA_DIR, 'keywords_ru_noun.csv'))
keywords_ru_adj.to_csv(pathjoin(DATA_DIR, 'keywords_ru_adj.csv'))
keywords_ru_adv.to_csv(pathjoin(DATA_DIR, 'keywords_ru_adv.csv'))
keywords_ru_verb.to_csv(pathjoin(DATA_DIR, 'keywords_ru_verb.csv'))

# %%
keywords_en_noun.to_csv(pathjoin(DATA_DIR, 'keywords_en_noun.csv'))
keywords_en_adj.to_csv(pathjoin(DATA_DIR, 'keywords_en_adj.csv'))
keywords_en_adv.to_csv(pathjoin(DATA_DIR, 'keywords_en_adv.csv'))
keywords_en_verb.to_csv(pathjoin(DATA_DIR, 'keywords_en_verb.csv'))
